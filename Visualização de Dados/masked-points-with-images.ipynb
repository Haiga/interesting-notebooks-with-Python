# %%
#Vamos fazer um grafo utilizando patplotlib
#Pontos ques estão concetados a  outros pontos

# %%
import numpy as np
total_vertices = 10

posicao_x = np.random.uniform(0,10, total_vertices)
posicao_y = np.random.uniform(0,10, total_vertices)

# %%
from tqdm import tqdm
from random import randint
from matplotlib import pyplot as plt

total_arestas = 10

for i in tqdm(range(total_arestas)):
    ponto1 = randint(0, 9)
    ponto2 = randint(0, 9)
    
    plt.plot([posicao_x[ponto1], posicao_x[ponto2]],[posicao_y[ponto1], posicao_y[ponto2]], 'b-')

plt.plot(posicao_x, posicao_y, 'ro')
plt.axis('off')

pass
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 429.58it/s]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
c = np.sqrt(area)
r = np.sqrt(x ** 2 + y ** 2)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
#Range para números quebrados espaçados entre 0.0.1
theta = np.arange(0, np.pi / 2, 0.01)
plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))

plt.show()

# %%
area2
# Out:
# masked_array(data=[--, --, --, --, --, --, 178.55726661902088,
#                    72.67319212907682, --, --, 9.399283703960183, --, --,
#                    --, --, --, --, --, --, --, --, 251.56554388407497,
#                    0.864761525793681, --, --, 33.15984622875554,
#                    299.6485831574722, 22.069712583674207,
#                    337.10771231476383, 0.016604132103523416,
#                    100.52699253677554, 372.4752473520801, --,
#                    74.55627428537787, --, --, --, --, 103.37134404770059,
#                    --, 83.40899943572327, 27.520073301354184, --, --, --,
#                    --, 24.949443406347257, --, 21.91709736914782, --, --,
#                    --, --, --, 101.66610251679653, --, 43.88553199315398,
#                    20.53362187605656, 46.48871839311715,
#                    36.631532435604264, --, 0.011342247065380678, --, --,
#                    --, --, --, 84.7818050636135, --, 217.36343724007878,
# ...

# %%
area
# Out:
# array([3.19894584e+00, 2.26239712e+00, 1.38613010e+02, 3.29030967e+02,
#        4.41415146e+01, 2.00188078e+02, 1.78557267e+02, 7.26731921e+01,
#        4.83859981e-01, 1.36359241e+02, 9.39928370e+00, 2.40021863e+01,
#        4.08112328e+01, 1.26751013e+02, 2.22472157e+02, 1.90156402e+02,
#        2.18535978e+02, 3.23833702e+02, 1.06831200e+02, 3.65989364e+01,
#        3.30759646e+01, 2.51565544e+02, 8.64761526e-01, 8.66844429e+01,
#        3.68677284e+02, 3.31598462e+01, 2.99648583e+02, 2.20697126e+01,
#        3.37107712e+02, 1.66041321e-02, 1.00526993e+02, 3.72475247e+02,
#        3.51378685e+02, 7.45562743e+01, 1.55164143e+02, 1.96485703e+02,
#        1.09224160e+01, 3.45045596e+02, 1.03371344e+02, 2.29213670e+02,
#        8.34089994e+01, 2.75200733e+01, 2.94364492e+02, 8.05440209e+01,
#        2.96395234e+02, 9.50407718e+00, 2.49494434e+01, 3.35389000e+01,
#        2.19170974e+01, 1.13808668e+02, 3.74232307e+02, 1.72340546e+02,
# ...

# %%
#Plot imagens no lugar de pontos
#https://stackoverflow.com/questions/22566284/matplotlib-how-to-plot-images-instead-of-points



import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
c = np.sqrt(area)
r = np.sqrt(x ** 2 + y ** 2)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
#Range para números quebrados espaçados entre 0.0.1
#theta = np.arange(0, np.pi / 2, 0.01)
#plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))

fig, ax = plt.subplots()
ax.scatter(x, y)
paths = ['indice.png']*N

from matplotlib.offsetbox import OffsetImage, AnnotationBbox
for x0, y0, path in zip(x, y, paths):
    ab = AnnotationBbox(OffsetImage(plt.imread(path)), (x0, y0), frameon=False)
    ax.add_artist(ab)

# %%
# !pip install pillow
#No caso de precisar fazer redimensionsamentos, cortes ... 
#Processamento de imagens com python
#https://auth0.com/blog/image-processing-in-python-with-pillow/
from PIL import Image

image = Image.open('indice.png')
new_image = image.resize((20, 20))
new_image.save('indice20.png')

print(image.size)
print(new_image.size)
# Out:
# ...
# (225, 225)
# (20, 20)

# %%
#Plot imagens no lugar de pontos
#https://stackoverflow.com/questions/22566284/matplotlib-how-to-plot-images-instead-of-points



import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 100
r0 = 0.6
x = 0.9 * np.random.rand(N)
y = 0.9 * np.random.rand(N)
area = (20 * np.random.rand(N))**2  # 0 to 10 point radii
c = np.sqrt(area)
r = np.sqrt(x ** 2 + y ** 2)
area1 = np.ma.masked_where(r < r0, area)
area2 = np.ma.masked_where(r >= r0, area)
plt.scatter(x, y, s=area1, marker='^', c=c)
plt.scatter(x, y, s=area2, marker='o', c=c)
# Show the boundary between the regions:
#Range para números quebrados espaçados entre 0.0.1
#theta = np.arange(0, np.pi / 2, 0.01)
#plt.plot(r0 * np.cos(theta), r0 * np.sin(theta))

fig, ax = plt.subplots()
ax.scatter(x, y)
paths = ['indice20.png']*N

from matplotlib.offsetbox import OffsetImage, AnnotationBbox
for x0, y0, path in zip(x, y, paths):
    ab = AnnotationBbox(OffsetImage(plt.imread(path)), (x0, y0), frameon=False)
    ax.add_artist(ab)
